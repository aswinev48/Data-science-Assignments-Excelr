# %% [markdown]
# ## HYPOTHESIS TESTING

# %% [markdown]
# ### Background:

# %% [markdown]
# ##### Bombay hospitality Ltd. operates a franchise model for producing exotic Norwegian dinners throughout New England. The operating cost for a franchise in a week (W) is given by the equation W = $1,000 + $5X, where X represents the number of units produced in a week. Recent feedback from restaurant owners suggests that this cost model may no longer be accurate, as their observed weekly operating costs are higher.

# %% [markdown]
# ### Objective:

# %% [markdown]
# ##### To investigate the restaurant owners' claim about the increase in weekly operating costs using hypothesis testing.

# %% [markdown]
# #### 1. State the Hypotheses statement:

# %%
import numpy as np
import pandas as pd

# %%
# H0 -> observed weekly operating costs are not higher
# Ha -> observed weekly operating costs are higher

# %% [markdown]
# #### 2. Calculate the Test Statistic:

# %%
X=600
x_bar=3050
pop_mean=1000+5*600
pop_std=5*25
n=25
alpha=0.05

# %%
z_stat=(x_bar-pop_mean)/(pop_std/np.sqrt(n))
z_stat
# Out:
# -38.0

# %% [markdown]
# #### 3) Determine the Probability and compare:

# %%
import scipy.stats as stats
from statsmodels.stats.weightstats import ztest

# %%
# Confidence Interval = 95 %
# Alpha = 0.05 %

# %%
p_value=1-stats.norm.cdf(z_stat)
p_value
# Out:
# 1.0

# %%
if p_value<alpha:
    p_value_dec="Reject H0"
else:
    p_value_dec="Fail to reject H0"
print(f"Decision based on p-value: {p_value_dec}")
# Out:
# Decision based on p-value: Fail to reject H0

# %% [markdown]
# #### 4) Make a Decision:

# %%
z_critical=stats.norm.ppf(0.975)
z_critical
# Out:
# 1.959963984540054

# %%
if z_critical<z_stat:
    critical_value_dec="Reject H0"
else:
    critical_value_dec="Fail to reject H0"
print(f"Decison based on critical_value: {critical_value_dec}")
# Out:
# Decison based on critical_value: Fail to reject H0

# %% [raw]
# Based on the answer in step 3 and step 4, we conclude that we fail to reject H0 and the null hypothesis(H0) is accepted. So therefore "Observed weekly operating costs are not higher". We dont have enough evidence at 5% significance level to support the owners claim that the weekly operation costs are higher than the theoretical model.

# %% [markdown]
# ## ESTIMATION AND CONFIDENCE INTERVALS

# %% [markdown]
# ### Background

# %% [markdown]
# ##### In quality control processes, especially when dealing with high-value items, destructive sampling is a necessary but costly method to ensure product quality. The test to determine whether an item meets the quality standards destroys the item, leading to the requirement of small sample sizes due to cost constraints.

# %% [markdown]
# ### Scenario

# %% [markdown]
# ##### A manufacturer of print-heads for personal computers is interested in estimating the mean durability of their print-heads in terms of the number of characters printed before failure. To assess this, the manufacturer conducts a study on a small sample of print-heads due to the destructive nature of the testing process.

# %% [markdown]
# ##### a) Build 99% Confidence Interval Using Sample Standard Deviation

# %%
data=np.array([1.13,1.55,1.43,0.92,1.25,1.36,1.32,0.85,1.07,1.48,1.20,1.33,1.18,1.22,1.29])

# %%
x_bar=np.mean(data)
x_bar
# Out:
# 1.2386666666666666

# %%
s=np.std(data,ddof=1)
s
# Out:
# 0.19316412956959936

# %%
sample_size=len(data)
sample_size
# Out:
# 15

# %%
degree_of_freedom=sample_size-1
degree_of_freedom
# Out:
# 14

# %%
ci=0.99
alpha=1-ci

# %%
t_critical=stats.t.ppf(0.995,14)
t_critical
# Out:
# 2.976842734370834

# %%
margin_of_error=t_critical*(s/np.sqrt(sample_size))
margin_of_error
# Out:
# 0.14846932822817596

# %%
### Calculating the lower and upper bound for pop mean with 99% CI

# %%
lower_bound=x_bar-margin_of_error
upper_bound=x_bar+margin_of_error

# %%
print(lower_bound,',',upper_bound)
# Out:
# 1.0901973384384906 , 1.3871359948948425

# %% [markdown]
# ##### b) Build 99% Confidence Interval Using Known Population Standard Deviation

# %%
pop_std=0.2

# %%
z_critical=stats.norm.ppf(0.995)
z_critical
# Out:
# 2.5758293035489004

# %%
margin_of_error=z_critical*(pop_std/np.sqrt(sample_size))
margin_of_error
# Out:
# 0.13301525327090588

# %%
## Calculating the pop mean

# %%
lower_mean=x_bar-margin_of_error
upper_mean=x_bar+ma
